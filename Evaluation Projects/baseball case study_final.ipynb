# %% [markdown]
# # Baseball case_study

# %% [markdown]
# # Problem Statement:

# %% [markdown]
# This dataset utilizes data from 2014 Major League Baseball seasons in order to develop an algorithm that predicts the number of wins for a given team in the 2015 season based on several different indicators of success. There are 16 different features that will be used as the inputs to the machine learning and the output will be a value that represents the number of wins.

# %% [markdown]
# -- Input features: Runs, At Bats, Hits, Doubles, Triples, Homeruns, Walks, Strikeouts, Stolen Bases, Runs Allowed, Earned Runs, Earned Run Average (ERA), Shutouts, Saves, Complete Games and Errors

# %% [markdown]
# -- Output: Number of predicted wins (W)

# %%
import pandas as pd

# %%
baseball=pd.read_csv('baseball_case study.csv')
baseball
# Out:
#       W    R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  \
# 0    95  724  5575  1497  300  42  139  383   973  104  641  601  3.73   2
# 1    83  696  5467  1349  277  44  156  439  1264   70  700  653  4.07   2
# 2    81  669  5439  1395  303  29  141  533  1157   86  640  584  3.67  11
# 3    76  622  5533  1381  260  27  136  404  1231   68  701  643  3.98   7
# 4    74  689  5605  1515  289  49  151  455  1259   83  803  746  4.64   7
# 5    93  891  5509  1480  308  17  232  570  1151   88  670  609  3.80   7
# 6    87  764  5567  1397  272  19  212  554  1227   63  698  652  4.03   3
# 7    81  713  5485  1370  246  20  217  418  1331   44  693  646  4.05   0
# 8    80  644  5485  1383  278  32  167  436  1310   87  642  604  3.74   1
# 9    78  748  5640  1495  294  33  161  478  1148   71  753  694  4.31   3
# 10   88  751  5511  1419  279  32  172  503  1233  101  733  680  4.24   5
# ...

# %%
baseball.columns
# Out:
# Index(['W', 'R', 'AB', 'H', '2B', '3B', 'HR', 'BB', 'SO', 'SB', 'RA', 'ER',
#        'ERA', 'CG', 'SHO', 'SV', 'E'],
#       dtype='object')

# %% [markdown]
# # Renaming columns:

# %%
baseball=baseball.rename(columns={'R':'Runs'})
baseball=baseball.rename(columns={'AB':'At Bats'})
baseball=baseball.rename(columns={'H':'Hits'})
baseball=baseball.rename(columns={'2B':'Doubles'})
baseball=baseball.rename(columns={'3B':'Triples'})
baseball=baseball.rename(columns={'HR':'Homeruns'})
baseball=baseball.rename(columns={'BB':'Walks'})
baseball=baseball.rename(columns={'SO':'Strikeouts'})
baseball=baseball.rename(columns={'SB':'Stolen Bases'})
baseball=baseball.rename(columns={'RA':'Runs Allowed'})
baseball=baseball.rename(columns={'ER':'Earned Runs'})
baseball=baseball.rename(columns={'ERA':'Earned Run Average'})
baseball=baseball.rename(columns={'CG':'Complete Games'})
baseball=baseball.rename(columns={'SHO':'Shutouts'})
baseball=baseball.rename(columns={'SV':'Saves'})
baseball=baseball.rename(columns={'E':'Errors'})
baseball=baseball.rename(columns={'W':'Wins'})
baseball.columns
# Out:
# Index(['Wins', 'Runs', 'At Bats', 'Hits', 'Doubles', 'Triples', 'Homeruns',
#        'Walks', 'Strikeouts', 'Stolen Bases', 'Runs Allowed', 'Earned Runs',
#        'Earned Run Average', 'Complete Games', 'Shutouts', 'Saves', 'Errors'],
#       dtype='object')

# %% [markdown]
# # About Columns:

# %% [markdown]
# 1.Wins: Number of games where pitcher was pitching while their team took the lead and went on to win, also the starter needs to pitch at least 5 innings of work.
#
# 2.Runs: Runs Scored:times reached home plate legally and safely.
#
# 3.At Bats:  At bat: plate appearances, not including bases on balls, being hit by pitch, sacrifices, interference, or obstruction.
#
# 4.Hits: Hit: reaching base because of a batted, fair ball without error by the defense.
#
# 5.Doubles: Double: hits on which the batter reaches second base safely without the contribution of a fielding error.
#
# 6.Triples: Triple: hits on which the batter reaches third base safely without the contribution of a fielding error.
#
# 7.Homeruns: Home runs: hits on which the batter successfully touched all four bases, without the contribution of a fielding error.
#
# 8.Walks: Base on balls (also called a "walk"): hitter not swinging at four pitches called out of the strike zone and awarded first base.
#
# 9.Strikeouts: Strikeout: number of batters who received strike three.
#
# 10.Stolen Bases: Stolen base: number of bases advanced by the runner while the ball is in the possession of the defense.
#
# 11.Runs Allowed: Run average: number of runs allowed times nine divided by innings pitched.
#
# 12.Earned Runs: Earned run: number of runs that did not occur as a result of errors or passed balls.
#
# 13.Earned Run Average: Earned run average: total number of earned runs (see "ER" above), multiplied by 9, divided by innings pitched.
#
# 14.Complete Games: Complete game: number of games where player was the only pitcher for their team.
#
# 15.Shutouts: Shutout: number of complete games pitched with no runs allowed.
#
# 16.Saves: Save: number of games where the pitcher enters a game led by the pitcher's team, finishes the game without surrendering the lead, is not the winning pitcher, and either (a) the lead was three runs or fewer when the pitcher entered the game; (b) the potential tying run was on base, at bat, or on deck; or (c) the pitcher pitched three or more innings.
#
# 17.Errors: Errors: number of times a fielder fails to make a play he should have made with common effort, and the offense benefits as a result.

# %%
baseball.isnull().sum()
# Out:
# Wins                  0
# Runs                  0
# At Bats               0
# Hits                  0
# Doubles               0
# Triples               0
# Homeruns              0
# Walks                 0
# Strikeouts            0
# Stolen Bases          0
# Runs Allowed          0
# Earned Runs           0
# Earned Run Average    0
# Complete Games        0
# Shutouts              0
# Saves                 0
# Errors                0
# dtype: int64

# %%
baseball.dtypes
# Out:
# Wins                    int64
# Runs                    int64
# At Bats                 int64
# Hits                    int64
# Doubles                 int64
# Triples                 int64
# Homeruns                int64
# Walks                   int64
# Strikeouts              int64
# Stolen Bases            int64
# Runs Allowed            int64
# Earned Runs             int64
# Earned Run Average    float64
# Complete Games          int64
# Shutouts                int64
# Saves                   int64
# Errors                  int64
# dtype: object

# %% [markdown]
# # EDA:

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
plt.figure(figsize=(15,30),facecolor='white')
plotnumber=1
for column in baseball:
    if plotnumber<=20:
        ax=plt.subplot(9,2,plotnumber)
        sns.distplot(baseball[column])
        plt.xlabel(column,fontsize=14)
    plotnumber+=1
plt.tight_layout()

# %%
sns.pairplot(x_vars='Runs',y_vars='Wins',data=baseball,size=4)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.show()

# %% [markdown]
# Here we can see the range of runs is between 573 to 900 and the highest frequency is between 610 to 760

# %%
sns.pairplot(x_vars='At Bats',y_vars='Wins',data=baseball,size=4)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.show()

# %% [markdown]
# Here we can see range is between 5380 to 5650

# %%
sns.pairplot(x_vars='Hits',y_vars='Wins',data=baseball,size=4)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.show()

# %% [markdown]
# Hits are in the range 1200 to 1550 highest frequency is between 1200-1425

# %%
sns.pairplot(x_vars='Doubles',y_vars='Wins',data=baseball,size=4)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.show()

# %% [markdown]
# Doubles are in the range 200 to 350 and as the doubles increases Wins also increases.

# %%
sns.pairplot(x_vars='Triples',y_vars='Wins',data=baseball,size=4)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.show()

# %% [markdown]
# Triples are in the range 5 to 50 and at triples value 40 wins is highest=100

# %%
sns.pairplot(x_vars='Homeruns',y_vars='Wins',data=baseball,size=5)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.show()

# %% [markdown]
# Homeruns are in the range 100 to 250 and as the homeruns increases Wins also increases

# %%
sns.pairplot(x_vars='Walks',y_vars='Wins',data=baseball,size=5)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.show()

# %% [markdown]
# Walks are in the range 375 to 575 and as the walks increases Wins also increases

# %%
sns.pairplot(x_vars='Strikeouts',y_vars='Wins',data=baseball,size=5)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.show()

# %% [markdown]
# Strikeouts are between 9500 to 1550 and the highest frequency is between 1100-1400

# %%
sns.lineplot(x='Stolen Bases',y='Wins',data=baseball)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.show()

# %% [markdown]
# Stolen Bases are in the range 42 to 130

# %%
sns.pairplot(x_vars='Runs Allowed',y_vars='Wins',data=baseball,size=5)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.show()

# %% [markdown]
# Runs allowed are in the range 500 to 850 and as Runs allowed increases Wins goes on decreasing

# %%
sns.pairplot(x_vars='Earned Runs',y_vars='Wins',data=baseball,size=5)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.show()

# %% [markdown]
# Earned Runs are in the range 480 to 800 and as Earned Runs increases Wins goes on decreasing

# %%
sns.pairplot(x_vars='Earned Run Average',y_vars='Wins',data=baseball,size=5)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.show()

# %% [markdown]
# Earned Run Average are in the range 3 to 5.2 and as Earned Run Average goes on increasing Wins goes on decreasing

# %%
sns.pairplot(x_vars='Complete Games',y_vars='Wins',data=baseball,size=5)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.show()

# %% [markdown]
# Complete Games are between 0 to 12

# %%
sns.pairplot(x_vars='Shutouts',y_vars='Wins',data=baseball,size=5)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.show()

# %% [markdown]
# Shutouts are in the range 4 to 24

# %%
sns.pairplot(x_vars='Saves',y_vars='Wins',data=baseball,size=5)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.show()

# %% [markdown]
# Saves are in the range 25 to 65 and as the saves increases wins also increases

# %%
sns.pairplot(x_vars='Errors',y_vars='Wins',data=baseball,size=5)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.show()

# %% [markdown]
# Errors are in the range 70 to 130 and highest frequency is between 80-100

# %% [markdown]
# # Correlation:

# %%
baseball.corr()
# Out:
#                         Wins      Runs   At Bats      Hits   Doubles  \
# Wins                1.000000  0.430751 -0.087947  0.037612  0.427797
# Runs                0.430751  1.000000  0.319464  0.482856  0.560084
# At Bats            -0.087947  0.319464  1.000000  0.739122  0.453370
# Hits                0.037612  0.482856  0.739122  1.000000  0.566847
# Doubles             0.427797  0.560084  0.453370  0.566847  1.000000
# Triples            -0.251118 -0.070072  0.435422  0.478694  0.220490
# Homeruns            0.307407  0.671283 -0.066983 -0.090855  0.056292
# Walks               0.484342  0.402452 -0.136414 -0.118281  0.302700
# Strikeouts          0.111850 -0.054726 -0.106022 -0.398830 -0.150752
# Stolen Bases       -0.157234  0.081367  0.372618  0.413444  0.195027
# Runs Allowed       -0.812952 -0.041623  0.316010  0.224324 -0.218160
# Earned Runs        -0.809435 -0.041245  0.309686  0.252489 -0.235531
# Earned Run Average -0.819600 -0.049281  0.255551  0.231172 -0.254854
# ...

# %%
plt.figure(figsize=(20,18))
sns.heatmap(baseball.corr(),annot=True, linewidth=0.2,linecolor='white',fmt='0.2f',cmap='Greens')
plt.xticks(fontsize=16)
plt.yticks(fontsize=16)
plt.show()

# %% [markdown]
# # Outcome of correlation:

# %% [markdown]
# All columns are positively correlated with the target column.
#
# Saves, Runs, Doubles, Walks and Shutouts have 67, 43, 43, 48, 47 percent of correlation with target column which can be considered as strong bond.
#
# Homeruns, Strikeouts, Complete Games, Hits have 31, 11, 8 and 4 percent of correlation with target column which can considered as good bond.
#
# Whereas At bats, Triples, Stolen Bases, Runs allowed, Earned Runs, Earned Run Average, Errors have slight negative correlation.
#
# Max correlation: Saves
#
# Min correlation: Earned Run Average

# %% [markdown]
# # Describing datasets with heatmap:

# %%
baseball.describe()
# Out:
#              Wins        Runs      At Bats         Hits     Doubles  \
# count   30.000000   30.000000    30.000000    30.000000   30.000000
# mean    80.966667  688.233333  5516.266667  1403.533333  274.733333
# std     10.453455   58.761754    70.467372    57.140923   18.095405
# min     63.000000  573.000000  5385.000000  1324.000000  236.000000
# 25%     74.000000  651.250000  5464.000000  1363.000000  262.250000
# 50%     81.000000  689.000000  5510.000000  1382.500000  275.500000
# 75%     87.750000  718.250000  5570.000000  1451.500000  288.750000
# max    100.000000  891.000000  5649.000000  1515.000000  308.000000
#
#          Triples    Homeruns       Walks  Strikeouts  Stolen Bases  \
# count  30.000000   30.000000   30.000000    30.00000     30.000000
# mean   31.300000  163.633333  469.100000  1248.20000     83.500000
# std    10.452355   31.823309   57.053725   103.75947     22.815225
# min    13.000000  100.000000  375.000000   973.00000     44.000000
# ...

# %%
plt.figure(figsize=(20,18))
sns.heatmap(baseball.describe().transpose(),annot=True, fmt='0.2f', linewidth=0.2, cmap='Blues', linecolor='black')
plt.xticks(fontsize=16)
plt.yticks(fontsize=16)
plt.title('Variable Summary',fontsize=18)
plt.show()

# %% [markdown]
# # Outcome of describe of datasets:

# %% [markdown]
# From above we are determining mean, standard deviation, min. and max. value of each column, which will furthur help in data cleaning.

# %% [markdown]
# Total number of rows and columns in dataset:
#
# 1.30 rows
#
# 2.17 columns

# %% [markdown]
# Runs:
#
#     1.Mean=688.23
#     2.std.=58.76
#     3.max_value=891.00
#     4.min_value=573.00
#
# At Bats:
#
#     1.Mean=5516.27
#     2.std.=70.47
#     3.max_value=5649.00
#     4.min_value=5385.00
#
# Hits:
#
#     1.Mean=1403.53
#     2.std.=57.14
#     3.max_value=1515.00
#     4.min_value=1324.00
#
# Doubles:
#
#     1.Mean=274.73
#     2.std.=18.10
#     3.max_value=308.00
#     4.min_value=236.00
#
# Triples:
#
#     1.Mean=31.30
#     2.std.=10.45
#     3.max_value=49.00
#     4.min_value=13.00
#
# Homeruns:
#
#     1.Mean=163.63
#     2.std.=31.82
#     3.max_value=232.00
#     4.min_value=100.00
#
# Walks:
#
#     1.Mean=469.10
#     2.std.=57.05
#     3.max_value=570.00
#     4.min_value=375.00
#
# Strikeouts:
#
#     1.Mean=1248.20
#     2.std.=103.76
#     3.max_value=1518.00
#     4.min_value=973.00
#
# Stolen Bases:
#
#     1.Mean=83.50
#     2.std.=22.82
#     3.max_value=134.00
#     4.min_value=44.00
#
# Runs Allowed:
#
#     1.Mean=688.23
#     2.std.=72.11
#     3.max_value=844.00
#     4.min_value=525.00
#
# Earned Runs:
#
#     1.Mean=635.83
#     2.std.=70.14
#     3.max_value=799.00
#     4.min_value=478.00
#
# Earned Run Average:
#
#     1.Mean=3.96
#     2.std.=0.45
#     3.max_value=5.04
#     4.min_value=2.94
#
# Complete Games:
#
#     1.Mean=3.47
#     2.std.=2.76
#     3.max_value=11.00
#     4.min_value=0.00
#
# Shutouts:
#
#     1.Mean=11.30
#     2.std.=4.12
#     3.max_value=21.00
#     4.min_value=4.00
#
# Saves:
#
#     1.Mean=43.07
#     2.std.=7.88
#     3.max_value=62.00
#     4.min_value=28.00
#
# Errors:
#
#     1.Mean=94.33
#     2.std.=13.96
#     3.max_value=126.00
#     4.min_value=75.00
#
# Wins:
#
#     1.Mean=80.97
#     2.std.=10.45
#     3.max_value=100.00
#     4.min_value=63.00
#
# Wins is our target column.

# %% [markdown]
# # Using subplot and distplot to check data are normalised or not, considering mean values.

# %%
baseball.columns
# Out:
# Index(['Wins', 'Runs', 'At Bats', 'Hits', 'Doubles', 'Triples', 'Homeruns',
#        'Walks', 'Strikeouts', 'Stolen Bases', 'Runs Allowed', 'Earned Runs',
#        'Earned Run Average', 'Complete Games', 'Shutouts', 'Saves', 'Errors'],
#       dtype='object')

# %%
import itertools

cols=['Runs',
     'At Bats',
     'Hits',
     'Doubles',
     'Triples',
     'Homeruns',
     'Walks',
     'Strikeouts',
     'Stolen Bases',
     'Runs Allowed',
     'Earned Runs',
     'Earned Run Average',
     'Complete Games',
     'Shutouts',
     'Saves',
     'Errors']
length=len(cols)
cs=['b','r','g','orange','teal','Cyan','orange','lime','purple','k','violet','r','g','b','lime','teal']
fig=plt.figure(figsize=(15,30))
for i,j,k in itertools.zip_longest(cols,range(length),cs):
    plt.subplot(8,2,j+1)
    ax=sns.distplot(baseball[i],color=k,rug=True)
    ax.set_facecolor('w')
    plt.axvline(baseball[i].mean(),linestyle='--',label='mean',color='k')
    plt.legend(loc='best')
    plt.title(i,color='navy')
    plt.xlabel('')

# %% [markdown]
# # Observation:

# %% [markdown]
# From above we can see that data is normalised for features and we can proceed with data cleaning.

# %%
baseball.hist(edgecolor='red',linewidth=2,figsize=(20,25))
# Out:
# array([[<AxesSubplot:title={'center':'Wins'}>,
#         <AxesSubplot:title={'center':'Runs'}>,
#         <AxesSubplot:title={'center':'At Bats'}>,
#         <AxesSubplot:title={'center':'Hits'}>],
#        [<AxesSubplot:title={'center':'Doubles'}>,
#         <AxesSubplot:title={'center':'Triples'}>,
#         <AxesSubplot:title={'center':'Homeruns'}>,
#         <AxesSubplot:title={'center':'Walks'}>],
#        [<AxesSubplot:title={'center':'Strikeouts'}>,
#         <AxesSubplot:title={'center':'Stolen Bases'}>,
#         <AxesSubplot:title={'center':'Runs Allowed'}>,
#         <AxesSubplot:title={'center':'Earned Runs'}>],
#        [<AxesSubplot:title={'center':'Earned Run Average'}>,
#         <AxesSubplot:title={'center':'Complete Games'}>,
#         <AxesSubplot:title={'center':'Shutouts'}>,
#         <AxesSubplot:title={'center':'Saves'}>],
#        [<AxesSubplot:title={'center':'Errors'}>, <AxesSubplot:>,
#         <AxesSubplot:>, <AxesSubplot:>]], dtype=object)

# %%
plt.figure(figsize=(20,15))
baseball.corr()['Wins'].sort_values(ascending=False).drop(['Wins']).plot(kind='bar',color='teal')
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.xlabel('Feature',fontsize=18)
plt.ylabel('Correlation with target column',fontsize=18)
plt.title('Correlation of features with the target column',fontsize=20)
plt.show()

# %%
baseball.isnull().sum()
# Out:
# Wins                  0
# Runs                  0
# At Bats               0
# Hits                  0
# Doubles               0
# Triples               0
# Homeruns              0
# Walks                 0
# Strikeouts            0
# Stolen Bases          0
# Runs Allowed          0
# Earned Runs           0
# Earned Run Average    0
# Complete Games        0
# Shutouts              0
# Saves                 0
# Errors                0
# dtype: int64

# %%
baseball.skew()
# Out:
# Wins                  0.047089
# Runs                  1.200786
# At Bats               0.183437
# Hits                  0.670254
# Doubles              -0.230650
# Triples               0.129502
# Homeruns              0.516441
# Walks                 0.158498
# Strikeouts           -0.156065
# Stolen Bases          0.479893
# Runs Allowed          0.045734
# Earned Runs           0.058710
# Earned Run Average    0.053331
# Complete Games        0.736845
# Shutouts              0.565790
# Saves                 0.657524
# Errors                0.890132
# dtype: float64

# %% [markdown]
# # Skewness:

# %% [markdown]
# We are taking Skewness threshold as +/-0.5. From above, columns which fall under skewness:
#
#     Runs, skewness=1.200786, Hits, skewness=0.670254, Complete Games, skewness=0.736845, Saves, skewness=0.657524,
#     Errors, skewness=0.890132

# %%
baseball.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 17 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Wins                30 non-null     int64
#  1   Runs                30 non-null     int64
#  2   At Bats             30 non-null     int64
#  3   Hits                30 non-null     int64
#  4   Doubles             30 non-null     int64
#  5   Triples             30 non-null     int64
#  6   Homeruns            30 non-null     int64
#  7   Walks               30 non-null     int64
#  8   Strikeouts          30 non-null     int64
#  9   Stolen Bases        30 non-null     int64
#  10  Runs Allowed        30 non-null     int64
#  11  Earned Runs         30 non-null     int64
#  12  Earned Run Average  30 non-null     float64
#  13  Complete Games      30 non-null     int64
#  14  Shutouts            30 non-null     int64
#  15  Saves               30 non-null     int64
# ...

# %% [markdown]
# From above we can have columns datatype and memory used by the dataframe.

# %% [markdown]
# # Outliers Checking:

# %% [markdown]
# To check outliers we are using boxplot.

# %%
baseball.plot(kind='box',subplots=True,layout=(4,5),figsize=(17,20),color='green')
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.show()

# %% [markdown]
# From above Runs, Earned Run Average, Shutouts and Errors have slight outliers.

# %% [markdown]
# # Removing outliers:

# %% [markdown]
# Checking the percentage of data falling under outliers.

# %%
from scipy.stats import zscore
import numpy as np

# %%
z=np.abs(zscore(baseball))
z.shape
# Out:
# (30, 17)

# %%
threshold=3
print(np.where(z>3))
# Out:
# (array([5], dtype=int64), array([1], dtype=int64))

# %%
baseball_new=baseball[(z<3).all(axis=1)]
print(baseball.shape)
print(baseball_new.shape)
# Out:
# (30, 17)
# (29, 17)

# %% [markdown]
# # Percentage Data Loss

# %%
loss_percent=(30-29)/30*100
print(loss_percent)
# Out:
# 3.3333333333333335

# %% [markdown]
# Percentage loss is not more than 5 percent.

# %% [markdown]
# We will try for IQR.

# %%
Q1=baseball.quantile(0.25)
Q3=baseball.quantile(0.75)
IQR=Q3-Q1
print(IQR)
# Out:
# Wins                   13.7500
# Runs                   67.0000
# At Bats               106.0000
# Hits                   88.5000
# Doubles                26.5000
# Triples                16.0000
# Homeruns               36.7500
# Walks                  73.0000
# Strikeouts            154.0000
# Stolen Bases           27.5000
# Runs Allowed           96.2500
# Earned Runs            92.0000
# Earned Run Average      0.5375
# Complete Games          4.7500
# Shutouts                4.0000
# Saves                   9.5000
# Errors                 10.7500
# dtype: float64

# %%
baseball_new1=baseball[-((baseball<(Q1-1.5*IQR)) |(baseball>(Q3 + 1.5 * IQR))).any(axis=1)]
print(baseball_new1.shape)
# Out:
# (20, 17)

# %%
percentage_loss=(30-20)/30*100
print(percentage_loss)
# Out:
# 33.33333333333333

# %% [markdown]
# Since the percentage loss in zscore is less, we will go with zscore over IQR.

# %% [markdown]
# # Dividing data in features and vectors:

# %%
x=baseball_new.drop(columns=['Wins'])
y=baseball_new['Wins']

# %%
x.dtypes
# Out:
# Runs                    int64
# At Bats                 int64
# Hits                    int64
# Doubles                 int64
# Triples                 int64
# Homeruns                int64
# Walks                   int64
# Strikeouts              int64
# Stolen Bases            int64
# Runs Allowed            int64
# Earned Runs             int64
# Earned Run Average    float64
# Complete Games          int64
# Shutouts                int64
# Saves                   int64
# Errors                  int64
# dtype: object

# %%
y.dtypes
# Out:
# dtype('int64')

# %% [markdown]
# Observing relationship between features and target vectors:

# %%
plt.figure(figsize=(10,30),facecolor='white')
plotnumber=1

for column in x:
    if plotnumber<=20:
        ax=plt.subplot(8,2,plotnumber)
        sns.barplot(y,x[column])
        plt.xlabel('wins',fontsize=14)
        plt.ylabel(column,fontsize=14)
    plotnumber+=1
plt.tight_layout()

# %% [markdown]
# # Transforming data to remove skewness:

# %%
baseball_new.skew()
# Out:
# Wins                  0.119013
# Runs                 -0.215364
# At Bats               0.169573
# Hits                  0.783772
# Doubles              -0.335304
# Triples               0.090124
# Homeruns              0.450862
# Walks                 0.151193
# Strikeouts           -0.233815
# Stolen Bases          0.494966
# Runs Allowed          0.018155
# Earned Runs           0.018461
# Earned Run Average    0.016693
# Complete Games        0.854980
# Shutouts              0.526943
# Saves                 0.627480
# Errors                0.840271
# dtype: float64

# %% [markdown]
# Using power_transform to remove skewness:

# %%
from sklearn.preprocessing import power_transform
x=power_transform(x,method='yeo-johnson')
x
# Out:
# array([[ 9.62543504e-01,  0.00000000e+00,  0.00000000e+00,
#          1.68518793e+00,  1.00615029e+00, -7.41927000e-01,
#         -1.60519802e+00, -2.55061247e+00,  9.36131648e-01,
#         -6.60978697e-01, -5.08052224e-01, -5.09292146e-01,
#         -3.07098204e-01, -7.87002186e-01,  1.53275292e+00,
#         -3.48265262e-01],
#        [ 2.98863300e-01,  0.00000000e+00,  0.00000000e+00,
#          1.38197902e-01,  1.18522654e+00, -1.09958425e-01,
#         -4.62095966e-01,  9.36832915e-02, -5.16377335e-01,
#          1.60225829e-01,  2.35800488e-01,  2.41440214e-01,
#         -3.07098204e-01,  2.36736538e-01,  3.12020186e-01,
#         -5.40819806e-01],
#        [-3.12105130e-01,  0.00000000e+00,  0.00000000e+00,
#          1.90738550e+00, -2.28819392e-01, -6.64354121e-01,
#          1.23209786e+00, -9.35611465e-01,  2.25038365e-01,
#         -6.74967476e-01, -7.52213881e-01, -6.42097599e-01,
#          2.01131531e+00, -2.52844176e-01, -6.64136739e-01,
#         -1.32612477e+00],
# ...

# %% [markdown]
# Applying Standard Scaler:

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
x_t=sc.fit_transform(x)
x_t
# Out:
# array([[ 9.62543504e-01,  0.00000000e+00,  0.00000000e+00,
#          1.68518793e+00,  1.00615029e+00, -7.41927000e-01,
#         -1.60519802e+00, -2.55061247e+00,  9.36131648e-01,
#         -6.60978697e-01, -5.08052224e-01, -5.09292146e-01,
#         -3.07098204e-01, -7.87002186e-01,  1.53275292e+00,
#         -3.48265262e-01],
#        [ 2.98863300e-01,  0.00000000e+00,  0.00000000e+00,
#          1.38197902e-01,  1.18522654e+00, -1.09958425e-01,
#         -4.62095966e-01,  9.36832915e-02, -5.16377335e-01,
#          1.60225829e-01,  2.35800488e-01,  2.41440214e-01,
#         -3.07098204e-01,  2.36736538e-01,  3.12020186e-01,
#         -5.40819806e-01],
#        [-3.12105130e-01,  0.00000000e+00,  0.00000000e+00,
#          1.90738550e+00, -2.28819392e-01, -6.64354121e-01,
#          1.23209786e+00, -9.35611465e-01,  2.25038365e-01,
#         -6.74967476e-01, -7.52213881e-01, -6.42097599e-01,
#          2.01131531e+00, -2.52844176e-01, -6.64136739e-01,
#         -1.32612477e+00],
# ...

# %%
y.value_counts()
# Out:
# 68     3
# 74     2
# 76     2
# 81     2
# 83     2
# 64     1
# 84     1
# 100    1
# 92     1
# 90     1
# 88     1
# 87     1
# 86     1
# 85     1
# 80     1
# 97     1
# 79     1
# 78     1
# 63     1
# 71     1
# 67     1
# 98     1
# 95     1
# Name: Wins, dtype: int64

# %%
print(x_t.shape)
print(y.shape)
# Out:
# (29, 16)
# (29,)

# %% [markdown]
# # Regressor Model Building:

# %% [markdown]
# # Linear Regression:

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score

# %%
lr=LinearRegression()
max_scr=0
for i in range(0,10000):
    x_train,x_test,y_train,y_test=train_test_split(x_t,y,random_state=i,test_size=0.20)
    lr.fit(x_train,y_train)
    pred_train=lr.predict(x_train)
    pred_test=lr.predict(x_test)
    if round(r2_score(y_train,pred_train)*100,2)==round(r2_score(y_test,pred_test)*100,2):
        print('At random state',i,'The model performs well')
        print('At random state:-',i)
        print('Training score is:-',r2_score(y_train,pred_train)*100)
        print('Testing score is:-',r2_score(y_test,pred_test)*100)
# Out:
# At random state 6054 The model performs well
# At random state:- 6054
# Training score is:- 93.64145538655933
# Testing score is:- 93.64280681711261
# At random state 8796 The model performs well
# At random state:- 8796
# Training score is:- 93.97095170902203
# Testing score is:- 93.9747646277578
# At random state 9167 The model performs well
# At random state:- 9167
# Training score is:- 93.81624217158664
# Testing score is:- 93.82288603969619

# %%
x_train_b,x_test_b,y_train_b,y_test_b=train_test_split(x_t,y,random_state=6054,test_size=0.20)

# %% [markdown]
# We are using random state 6054, as at random state 6054, it is giving highest accuracy.

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import cross_val_score

# %% [markdown]
# # Regularization

# %% [markdown]
# # 1.Lasso:

# %%
from sklearn.linear_model import Lasso
parameters={'alpha':[0.0001,0.001,0.01,0.1,1,10],'random_state':list(range(0,10))}
ls=Lasso()
grid_search=GridSearchCV(ls,parameters)
grid_search.fit(x_train,y_train)
print(grid_search.best_params_)
# Out:
# {'alpha': 0.1, 'random_state': 0}

# %%
ls=Lasso(alpha=0.1,random_state=0)
ls.fit(x_train_b,y_train_b)
ls.score(x_train_b,y_train_b)
pred_ls=ls.predict(x_test_b)

lss=r2_score(y_test_b,pred_ls)
for i in range(2,20):
    lsscore=cross_val_score(ls,x_t,y,cv=i)
    lsc=lsscore.mean()
    print('At cv:-',i)
    print('r2_score is:-',lss*100)
    print('cross validation score is:-',lsc*100)
    print('\n')
# Out:
# At cv:- 2
# r2_score is:- 92.59421130243567
# cross validation score is:- 66.267383585603
#
#
# At cv:- 3
# r2_score is:- 92.59421130243567
# cross validation score is:- 54.51262738526744
#
#
# At cv:- 4
# r2_score is:- 92.59421130243567
# cross validation score is:- 61.29940772479176
#
#
# At cv:- 5
# r2_score is:- 92.59421130243567
# cross validation score is:- 47.37613491918032
#
#
# At cv:- 6
# r2_score is:- 92.59421130243567
# cross validation score is:- 48.022584714015814
#
#
# At cv:- 7
# r2_score is:- 92.59421130243567
# cross validation score is:- 36.183916732549314
#
#
# At cv:- 8
# r2_score is:- 92.59421130243567
# cross validation score is:- 51.99178380056446
#
#
# At cv:- 9
# r2_score is:- 92.59421130243567
# cross validation score is:- -455.98490015519195
#
#
# At cv:- 10
# r2_score is:- 92.59421130243567
# cross validation score is:- -274.4910606994575
#
#
# At cv:- 11
# r2_score is:- 92.59421130243567
# cross validation score is:- -277.0164845360793
#
#
# At cv:- 12
# ...

# %%
print('At cv:-',2)
print('r2_score is:-',92.59421)
print('cross validation score is:-',66.26738)
# Out:
# At cv:- 2
# r2_score is:- 92.59421
# cross validation score is:- 66.26738

# %%
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
import numpy as np

# %%
print('Error')
print('mean absolute error:',mean_absolute_error(y_test_b,pred_ls))
print('mean squared error:',mean_squared_error(y_test_b,pred_ls))
print('root mean squared error:',np.sqrt(mean_squared_error(y_test_b,pred_ls)))
# Out:
# Error
# mean absolute error: 3.2216377661544677
# mean squared error: 12.614526748184582
# root mean squared error: 3.5516935042574524

# %%
plt.figure(figsize=(8,6))
plt.scatter(x=y_test_b,y=pred_ls,color='b')
plt.plot(y_test_b,y_test_b,color='r')
plt.xlabel('actual wins',fontsize=14)
plt.ylabel('predicted wins',fontsize=14)
plt.title('Lasso Regression',fontsize=14)
plt.show()

# %% [markdown]
# # 2.Ridge:

# %%
from sklearn.linear_model import Ridge
parameters={'alpha':[0.0001,0.001,0.01,0.1,1,10],'fit_intercept':[True,False],'normalize':[True,False],'copy_X':[True,False],'tol':[0.001,0.01,0.1],'random_state':list(range(0,10))}
rd=Ridge()
clf=GridSearchCV(rd,parameters)
clf.fit(x_train_b,y_train_b)
print(clf.best_params_)
# Out:
# {'alpha': 10, 'copy_X': True, 'fit_intercept': True, 'normalize': False, 'random_state': 0, 'tol': 0.001}

# %%
rd=Ridge(alpha=10,copy_X=True,fit_intercept=True,normalize=False,random_state=0,tol=0.001)
rd.fit(x_train_b,y_train_b)
pred_rd=rd.predict(x_test_b)
rds=r2_score(y_test_b,pred_rd)
print('r2 score is:',rds*100)
rdscore=cross_val_score(rd,x_t,y,cv=2)
rdc=rdscore.mean()
print('cross validation score is:',rdc*100)
# Out:
# r2 score is: 83.16328453025899
# cross validation score is: 56.16036836434463

# %%
print('Error')
print('mean absolute error:',mean_absolute_error(y_test_b,pred_rd))
print('mean squared error:',mean_squared_error(y_test_b,pred_rd))
print('root mean squared error:',np.sqrt(mean_squared_error(y_test_b,pred_rd)))
# Out:
# Error
# mean absolute error: 4.623182716334064
# mean squared error: 28.67853868345887
# root mean squared error: 5.355234699194693

# %%
plt.figure(figsize=(8,6))
plt.scatter(x=y_test_b,y=pred_rd,color='b')
plt.plot(y_test_b,y_test_b,color='r')
plt.xlabel('actual wins',fontsize=14)
plt.ylabel('predicted wins',fontsize=14)
plt.title('Ridge Regression',fontsize=14)
plt.show()

# %% [markdown]
# # Ensemble Techniques:

# %%
from sklearn.tree import DecisionTreeRegressor
parameters={'criterion':['mse','friedman_mse','mae'],'splitter':['best','random'],}
dtr=DecisionTreeRegressor()
clf=GridSearchCV(dtr,parameters)
clf.fit(x_train_b,y_train_b)

print(clf.best_params_)
# Out:
# {'criterion': 'friedman_mse', 'splitter': 'random'}

# %%
dtr=DecisionTreeRegressor(criterion='friedman_mse',splitter='random')
dtr.fit(x_train_b,y_train_b)
dtr.score(x_train_b,y_train_b)
pred_dtr=dtr.predict(x_test_b)
dts=r2_score(y_test_b,pred_dtr)
print('r2_score is:',dts*100)

dtscore=cross_val_score(dtr,x_t,y,cv=2)
dtc=dtscore.mean()
print('cross validation score is:',dtc*100)
# Out:
# r2_score is: 27.788649706457925
# cross validation score is: -76.61855212331173

# %%
print('Error')
print('mean absolute error:',mean_absolute_error(y_test_b,pred_dtr))
print('mean squared error:',mean_squared_error(y_test_b,pred_dtr))
print('root mean squared error:',np.sqrt(mean_squared_error(y_test_b,pred_dtr)))
# Out:
# Error
# mean absolute error: 8.333333333333334
# mean squared error: 123.0
# root mean squared error: 11.090536506409418

# %%
plt.figure(figsize=(8,6))
plt.scatter(x=y_test_b,y=pred_dtr,color='b')
plt.plot(y_test_b,y_test_b,color='r')
plt.xlabel('actual wins',fontsize=14)
plt.ylabel('predicted wins',fontsize=14)
plt.title('Decision Tree Regressor',fontsize=14)
plt.show()

# %%
from sklearn.ensemble import RandomForestRegressor
parameters={'criterion':['friedman_mse','mae'],'n_estimators':[100,200,300]}
rf=RandomForestRegressor()
clf=GridSearchCV(rf,parameters)
clf.fit(x_train_b,y_train_b)

print(clf.best_params_)
# Out:
# {'criterion': 'mae', 'n_estimators': 100}

# %%
rf=RandomForestRegressor(criterion='mae',n_estimators=100)
rf.fit(x_train_b,y_train_b)
rf.score(x_train_b,y_train_b)
pred_rf=rf.predict(x_test_b)
rfs=r2_score(y_test_b,pred_rf)
print('r2_score is:',rfs*100)

rfscore=cross_val_score(rf,x_t,y,cv=2)
rfc=rfscore.mean()
print('cross validation score is:',rfc*100)
# Out:
# r2_score is: 61.20830724070451
# cross validation score is: 10.482444253360313

# %%
print('Error')
print('mean absolute error:',mean_absolute_error(y_test_b,pred_rf))
print('mean squared error:',mean_squared_error(y_test_b,pred_rf))
print('root mean squared error:',np.sqrt(mean_squared_error(y_test_b,pred_rf)))
# Out:
# Error
# mean absolute error: 7.001666666666665
# mean squared error: 66.07518333333333
# root mean squared error: 8.128664301921523

# %%
plt.figure(figsize=(8,6))
plt.scatter(x=y_test_b,y=pred_rf,color='b')
plt.plot(y_test_b,y_test_b,color='r')
plt.xlabel('actual wins',fontsize=14)
plt.ylabel('predicted wins',fontsize=14)
plt.title('Random Forest Regressor',fontsize=14)
plt.show()

# %%
from sklearn.datasets import make_regression
from sklearn.ensemble import GradientBoostingRegressor
parameters = {'loss' : ['ls', 'lad', 'huber', 'quantile'],'n_estimators':[50,100,200],'criterion':['friedman_mse', 'mse']}
gbr=GradientBoostingRegressor()
clf = GridSearchCV(gbr,parameters)
clf.fit(x_train_b,y_train_b)

print(clf.best_params_)
# Out:
# {'criterion': 'mse', 'loss': 'lad', 'n_estimators': 100}

# %%
gbr=GradientBoostingRegressor(criterion='mse',loss='lad',n_estimators=100)
gbr.fit(x_train_b,y_train_b)
gbr.score(x_train_b,y_train_b)
pred_gbr=gbr.predict(x_test_b)
gbrs=r2_score(y_test_b,pred_gbr)
print('r2_score is:',gbrs*100)

gbrscore=cross_val_score(gbr,x_t,y,cv=2)
gbrc=rfscore.mean()
print('cross validation score is:',gbrc*100)
# Out:
# r2_score is: 53.94318903874078
# cross validation score is: 10.482444253360313

# %%
print('Error')
print('mean absolute error:',mean_absolute_error(y_test_b,pred_gbr))
print('mean squared error:',mean_squared_error(y_test_b,pred_gbr))
print('root mean squared error:',np.sqrt(mean_squared_error(y_test_b,pred_gbr)))
# Out:
# Error
# mean absolute error: 7.574262062329036
# mean squared error: 78.45010133734489
# root mean squared error: 8.857206181259691

# %%
plt.figure(figsize=(8,6))
plt.scatter(x=y_test_b,y=pred_gbr,color='b')
plt.plot(y_test_b,y_test_b,color='r')
plt.xlabel('actual wins',fontsize=14)
plt.ylabel('predicted wins',fontsize=14)
plt.title('Gradient Boost Regressor',fontsize=14)
plt.show()

# %%
from sklearn.svm import SVR

parameters = { 'kernel': ['linear', 'poly','rbf', 'sigmoid'],'gamma':['auto','scale']}
sv = SVR()
clf = GridSearchCV(sv,parameters)
clf.fit(x_train_b,y_train_b)

print(clf.best_params_)
# Out:
# {'gamma': 'auto', 'kernel': 'linear'}

# %%
sv = SVR(kernel = 'rbf', gamma = 'auto')
sv.fit(x_train_b, y_train_b)
sv.score(x_train_b, y_train_b)
pred_sv = sv.predict(x_test_b)

svs = r2_score(y_test_b,pred_sv)
print('R2 Score:',svs*100)

svscore = cross_val_score(sv,x_t,y,cv=2)
svc = svscore.mean() 
print('Cross Val Score:',svc*100)
# Out:
# R2 Score: 9.789685903370104
# Cross Val Score: -13.469750126218305

# %%
plt.figure(figsize=(8,6))
plt.scatter(x=y_test_b, y=pred_sv, color='b')
plt.plot(y_test_b,y_test_b, color='r')
plt.xlabel('Actual wins',fontsize=14)
plt.ylabel('Predicted wins',fontsize=14)
plt.title('Support vector regressor',fontsize=18)
plt.show()

# %% [markdown]
# # The best model is Lasso.Since the difference between the percentage score of cross validation and r2_score is optimum.

# %% [markdown]
# # Model Saving:

# %%
import pickle
filename='baseball case study_project.pk1'
pickle.dump(ls,open(filename,'wb'))

# %% [markdown]
# # Conclusion:

# %%
import numpy as np
a=np.array(y_test)
predicted=np.array(ls.predict(x_test_b))
baseball_com=pd.DataFrame({'original':a,'predicted':predicted},index=range(len(a)))
baseball_com
# Out:
#    original  predicted
# 0        81  82.316866
# 1        80  69.171185
# 2        79  66.878756
# 3        83  90.596033
# 4        84  97.673777
# 5        64  89.575199
