# %% [markdown]
# # Avacado Project

# %% [markdown]
# # Problem Statement:

# %% [markdown]
# Avocado is a fruit consumed by people heavily in the United States.

# %% [markdown]
# # Content

# %% [markdown]
# This data was downloaded from the Hass Avocado Board website in May of 2018 & compiled into a single CSV.
#
# The table below represents weekly 2018 retail scan data for National retail volume (units) and price. Retail scan data comes directly from retailers’ cash registers based on actual retail sales of Hass avocados.
#
# Starting in 2013, the table below reflects an expanded, multi-outlet retail data set. Multi-outlet reporting includes an aggregation of the following channels: grocery, mass, club, drug, dollar and military. The Average Price (of avocados) in the table reflects a per unit (per avocado) cost, even when multiple units (avocados) are sold in bags.
#
# The Product Lookup codes (PLU’s) in the table are only for Hass avocados. Other varieties of avocados (e.g. greenskins) are not included in this table.
#
# Some relevant columns in the dataset:

# %% [markdown]
# Date - The date of the observation
#
# AveragePrice - the average price of a single avocado
#
# type - conventional or organic
#
# year - the year
#
# Region - the city or region of the observation
#
# Total Volume - Total number of avocados sold
#
# 4046 - Total number of avocados with PLU 4046 sold
#
# 4225 - Total number of avocados with PLU 4225 sold
#
# 4770 - Total number of avocados with PLU 4770 sold

# %% [markdown]
# # Inspiration /Label

# %% [markdown]
# The dataset can be seen in two angles to find the region and find the average price .
#
# Task: One of Classification and other of Regression

# %%
import pandas as pd

# %%
avacado=pd.read_csv("avocado.csv")
avacado
# Out:
#        Unnamed: 0        Date  AveragePrice  Total Volume     4046       4225  \
# 0               0  2015-12-27          1.33      64236.62  1036.74   54454.85
# 1               1  2015-12-20          1.35      54876.98   674.28   44638.81
# 2               2  2015-12-13          0.93     118220.22   794.70  109149.67
# 3               3  2015-12-06          1.08      78992.15  1132.00   71976.41
# 4               4  2015-11-29          1.28      51039.60   941.48   43838.39
# ...           ...         ...           ...           ...      ...        ...
# 18244           7  2018-02-04          1.63      17074.83  2046.96    1529.20
# 18245           8  2018-01-28          1.71      13888.04  1191.70    3431.50
# 18246           9  2018-01-21          1.87      13766.76  1191.92    2452.79
# 18247          10  2018-01-14          1.93      16205.22  1527.63    2981.04
# 18248          11  2018-01-07          1.62      17489.58  2894.77    2356.13
#
# ...

# %%
avacado.columns
# Out:
# Index(['Unnamed: 0', 'Date', 'AveragePrice', 'Total Volume', '4046', '4225',
#        '4770', 'Total Bags', 'Small Bags', 'Large Bags', 'XLarge Bags', 'type',
#        'year', 'region'],
#       dtype='object')

# %% [markdown]
# # About Columns:

# %% [markdown]
# 1.Unnamed: 0 It is the serial number of each row.
#
# 2.Date: It is the date of observation.
#
# 3.AveragePrice: Average price of avacados.
#
# 4.Total Volume: Quantity of Avacados.
#
# 5.4046: Total number of avacados with PLU 4046 sold.
#
# 6.4225: Total number of avacados with PLU 4225 sold.
#
# 7.4770: Total number of avacados with PLU 4770 sold.
#
# 8.Total Bags: Total number of bags sold.
#
# 9.Small Bags: Number of small bags.
#
# 10.Large Bags: Number of large bags.
#
# 11.XLarge Bags: Number of extra large bags.
#
# 12.Type: Type of avacados.
#
# 13.Year: The year in which the observation is taken.
#
# 14.Region: The city or region of observation.

# %% [markdown]
# Here Unnamed: 0 is the serial number column, which we can drop, as it is not affecting our dataset.

# %%
avacado.drop(["Unnamed: 0"],axis=1,inplace=True)
avacado
# Out:
#              Date  AveragePrice  Total Volume     4046       4225    4770  \
# 0      2015-12-27          1.33      64236.62  1036.74   54454.85   48.16
# 1      2015-12-20          1.35      54876.98   674.28   44638.81   58.33
# 2      2015-12-13          0.93     118220.22   794.70  109149.67  130.50
# 3      2015-12-06          1.08      78992.15  1132.00   71976.41   72.58
# 4      2015-11-29          1.28      51039.60   941.48   43838.39   75.78
# ...           ...           ...           ...      ...        ...     ...
# 18244  2018-02-04          1.63      17074.83  2046.96    1529.20    0.00
# 18245  2018-01-28          1.71      13888.04  1191.70    3431.50    0.00
# 18246  2018-01-21          1.87      13766.76  1191.92    2452.79  727.94
# 18247  2018-01-14          1.93      16205.22  1527.63    2981.04  727.01
# 18248  2018-01-07          1.62      17489.58  2894.77    2356.13  224.53
#
#        Total Bags  Small Bags  Large Bags  XLarge Bags          type  year  \
# ...

# %%
avacado.isnull().sum()
# Out:
# Date            0
# AveragePrice    0
# Total Volume    0
# 4046            0
# 4225            0
# 4770            0
# Total Bags      0
# Small Bags      0
# Large Bags      0
# XLarge Bags     0
# type            0
# year            0
# region          0
# dtype: int64

# %%
avacado.dtypes
# Out:
# Date             object
# AveragePrice    float64
# Total Volume    float64
# 4046            float64
# 4225            float64
# 4770            float64
# Total Bags      float64
# Small Bags      float64
# Large Bags      float64
# XLarge Bags     float64
# type             object
# year              int64
# region           object
# dtype: object

# %% [markdown]
# # EDA

# %% [markdown]
# Distribution of Average Price

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
plt.figure(figsize=(10,8),facecolor='white')
sns.kdeplot(x='AveragePrice', data=avacado, fill=True, color='green')
# Out:
# <AxesSubplot:xlabel='AveragePrice', ylabel='Density'>

# %%
plt.figure(figsize=(10,8),facecolor='white')
sns.kdeplot(x='AveragePrice', hue='type', data=avacado, fill=True, color='orange', palette='Accent')
# Out:
# <AxesSubplot:xlabel='AveragePrice', ylabel='Density'>

# %%
plt.figure(figsize=(10,8),facecolor='white')
sns.kdeplot(x='AveragePrice', hue='year', data=avacado, fill=True, color='orange', palette='Blues')
# Out:
# <AxesSubplot:xlabel='AveragePrice', ylabel='Density'>

# %%
plt.figure(figsize=(10,8),facecolor='white')
sns.kdeplot(x='AveragePrice', hue='region', data=avacado, fill=True, color='orange', palette='Oranges')
# Out:
# <AxesSubplot:xlabel='AveragePrice', ylabel='Density'>

# %%
import itertools

cols=['Total Volume',
     '4046',
     '4225',
     '4770',
     'Total Bags',
     'Small Bags',
     'Large Bags',
     'XLarge Bags']
length=len(cols)
cs=['blue','red','green','orange','purple','black','grey','lime']
fig=plt.figure(figsize=(15,25))
for i,j,k in itertools.zip_longest(cols,range(length),cs):
    plt.subplot(4,2,j+1)
    ax=sns.kdeplot(avacado[i],color=k,palette=cs)
    ax.set_facecolor('w')
    plt.title(i,color='navy')
    plt.xlabel('')

# %% [markdown]
# Dropping Column 'Date', as it is affecting our dataset.

# %%
avacado.drop(['Date'] ,axis=1, inplace=True)
avacado
# Out:
#        AveragePrice  Total Volume     4046       4225    4770  Total Bags  \
# 0              1.33      64236.62  1036.74   54454.85   48.16     8696.87
# 1              1.35      54876.98   674.28   44638.81   58.33     9505.56
# 2              0.93     118220.22   794.70  109149.67  130.50     8145.35
# 3              1.08      78992.15  1132.00   71976.41   72.58     5811.16
# 4              1.28      51039.60   941.48   43838.39   75.78     6183.95
# ...             ...           ...      ...        ...     ...         ...
# 18244          1.63      17074.83  2046.96    1529.20    0.00    13498.67
# 18245          1.71      13888.04  1191.70    3431.50    0.00     9264.84
# 18246          1.87      13766.76  1191.92    2452.79  727.94     9394.11
# 18247          1.93      16205.22  1527.63    2981.04  727.01    10969.54
# 18248          1.62      17489.58  2894.77    2356.13  224.53    12014.15
#
#        Small Bags  Large Bags  XLarge Bags          type  year  \
# ...

# %% [markdown]
# Using LabelEncoder for 'type' and 'region'.

# %%
from sklearn.preprocessing import LabelEncoder

# %%
lencode=LabelEncoder()
avacado['type']=lencode.fit_transform(avacado['type'])
avacado['region']=lencode.fit_transform(avacado['region'])
avacado
# Out:
#        AveragePrice  Total Volume     4046       4225    4770  Total Bags  \
# 0              1.33      64236.62  1036.74   54454.85   48.16     8696.87
# 1              1.35      54876.98   674.28   44638.81   58.33     9505.56
# 2              0.93     118220.22   794.70  109149.67  130.50     8145.35
# 3              1.08      78992.15  1132.00   71976.41   72.58     5811.16
# 4              1.28      51039.60   941.48   43838.39   75.78     6183.95
# ...             ...           ...      ...        ...     ...         ...
# 18244          1.63      17074.83  2046.96    1529.20    0.00    13498.67
# 18245          1.71      13888.04  1191.70    3431.50    0.00     9264.84
# 18246          1.87      13766.76  1191.92    2452.79  727.94     9394.11
# 18247          1.93      16205.22  1527.63    2981.04  727.01    10969.54
# 18248          1.62      17489.58  2894.77    2356.13  224.53    12014.15
#
#        Small Bags  Large Bags  XLarge Bags  type  year  region
# ...

# %%
plt.figure(figsize=(12,25),facecolor='w')
plotnumber=1
for column in avacado :
    if plotnumber<=20:
        ax=plt.subplot(7,2,plotnumber)
        sns.distplot(avacado[column], color='Orange')
        plt.xlabel(column,fontsize=14)
    plotnumber+=1
plt.tight_layout()

# %% [markdown]
# # Correlation:

# %%
avacado.corr()
# Out:
#               AveragePrice  Total Volume      4046      4225      4770  \
# AveragePrice      1.000000     -0.192752 -0.208317 -0.172928 -0.179446
# Total Volume     -0.192752      1.000000  0.977863  0.974181  0.872202
# 4046             -0.208317      0.977863  1.000000  0.926110  0.833389
# 4225             -0.172928      0.974181  0.926110  1.000000  0.887855
# 4770             -0.179446      0.872202  0.833389  0.887855  1.000000
# Total Bags       -0.177088      0.963047  0.920057  0.905787  0.792314
# Small Bags       -0.174730      0.967238  0.925280  0.916031  0.802733
# Large Bags       -0.172940      0.880640  0.838645  0.810015  0.698471
# XLarge Bags      -0.117592      0.747157  0.699377  0.688809  0.679861
# type              0.615845     -0.232434 -0.225819 -0.232289 -0.210027
# year              0.093197      0.017193  0.003353 -0.009559 -0.036531
# region           -0.011716      0.174176  0.192073  0.145726  0.095252
#
# ...

# %%
plt.figure(figsize=(15,10))
sns.heatmap(avacado.corr(),annot=True,linewidth=0.2,linecolor='white',fmt='0.2f')
plt.show()

# %% [markdown]
# # Outcome of correlation:

# %% [markdown]
# Only Type and year are positively correlated with target column with 62 and 9 percent. Else are negatively correlated which shows data is highly skewed.
#
# Max correlation: type
#
# Min correlation: 4046

# %% [markdown]
# # Describing datasets with heatmap:

# %%
avacado.describe()
# Out:
#        AveragePrice  Total Volume          4046          4225          4770  \
# count  18249.000000  1.824900e+04  1.824900e+04  1.824900e+04  1.824900e+04
# mean       1.405978  8.506440e+05  2.930084e+05  2.951546e+05  2.283974e+04
# std        0.402677  3.453545e+06  1.264989e+06  1.204120e+06  1.074641e+05
# min        0.440000  8.456000e+01  0.000000e+00  0.000000e+00  0.000000e+00
# 25%        1.100000  1.083858e+04  8.540700e+02  3.008780e+03  0.000000e+00
# 50%        1.370000  1.073768e+05  8.645300e+03  2.906102e+04  1.849900e+02
# 75%        1.660000  4.329623e+05  1.110202e+05  1.502069e+05  6.243420e+03
# max        3.250000  6.250565e+07  2.274362e+07  2.047057e+07  2.546439e+06
#
#          Total Bags    Small Bags    Large Bags    XLarge Bags          type  \
# count  1.824900e+04  1.824900e+04  1.824900e+04   18249.000000  18249.000000
# mean   2.396392e+05  1.821947e+05  5.433809e+04    3106.426507      0.499918
# ...

# %%
plt.figure(figsize=(15,10))
sns.heatmap(avacado.describe().transpose(),annot=True,fmt='0.2f',linewidth=0.2,cmap='Greens',linecolor='black')
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.title('Variable Summary',fontsize=15)
plt.show()

# %% [markdown]
# # Outcome of describe of datasets:

# %% [markdown]
# From above we are determining mean, standard deviation, min. and max. value of each column, which will furthur help in data cleaning.

# %% [markdown]
# Total number of rows and columns in dataset:
#
#     1.18249 rows
#
#     2.12 columns

# %% [markdown]
# Total volume:
#
#     1.Mean=850644.01
#     2.std=3453545.36
#     3.max_value=62505646.52
#     4.min_value=84.56
#
# 4046:
#
#     1.Mean=293008.42
#     2.std=1264989.08
#     3.max_value=22743616.17
#     4.min_value=0.00
#
# 4225:
#
#     1.Mean=295154.57
#     2.std=1204120.40
#     3.max_value=20470572.61
#     4.min_value=0.00
#
# 4770:
#
#     1.Mean=22839.74
#     2.std=107464.07
#     3.max_value=2546439.11
#     4.min_value=0.00
#
# Total Bags:
#
#     1.Mean=239639.20
#     2.std=986242.40
#     3.max_value=19373134.37
#     4.min_value=0.00
#
# Small Bags:
#
#     1.Mean=182194.69
#     2.std=746178.51
#     3.max_value=13384586.80
#     4.min_value=0.00
#
# Large Bags:
#
#     1.Mean=54338.09
#     2.std=243965.96
#     3.max_value=5719096.61
#     4.min_value=0.00
#
# XLarge Bags:
#
#     1.Mean=3106.43
#     2.std=17692.89
#     3.max_value=551693.65
#     4.min_value=0.00
#
# type:
#
#     1.Mean=0.50
#     2.std=0.50
#     3.max_value=1.00
#     4.min_value=0.00
#
# year:
#
#     1.Mean=2016.15
#     2.std=0.94
#     3.max_value=2018.00
#     4.min_value=2015.00
#
# region:
#
#     1.Mean=26.50
#     2.std=15.58
#     3.max_value=53.00
#     4.min_value=8.00
#
# AveragePrice:
#
#     1.Mean=1.41
#     2.std=0.40
#     3.max_value=3.25
#     4.min_value=0.44
#
# AveragePrice and region are our target column.

# %% [markdown]
# # Using subplot and distplot to check data are normalised or not, considering mean values.

# %% [markdown]
# 1st we will exclude AveragePrice and then region.

# %%
import itertools

cols=['Total Volume',
     '4046',
     '4225',
     '4770',
     'Total Bags',
     'Small Bags',
     'Large Bags',
     'XLarge Bags',
     'type',
     'year',
     'region']
length=len(cols)
cs=['b','r','g','c','m','k','lime','purple','orange','m','k']
fig=plt.figure(figsize=(13,25))
for i,j,k in itertools.zip_longest(cols,range(length),cs):
    plt.subplot(6,2,j+1)
    ax=sns.distplot(avacado[i],color=k,rug=True)
    ax.set_facecolor('w')
    plt.axvline(avacado[i].mean(),linestyle='--',label='mean',color='k')
    plt.legend(loc='best')
    plt.title(i,color='navy')
    plt.xlabel('')

# %% [markdown]
# Excluding region.

# %%
import itertools

cols=['Total Volume',
     '4046',
     '4225',
     '4770',
     'Total Bags',
     'Small Bags',
     'Large Bags',
     'XLarge Bags',
     'type',
     'year',
     'AveragePrice']
length=len(cols)
cs=['b','r','g','c','m','k','lime','purple','orange','m','k']
fig=plt.figure(figsize=(13,25))
for i,j,k in itertools.zip_longest(cols,range(length),cs):
    plt.subplot(6,2,j+1)
    ax=sns.distplot(avacado[i],color=k,rug=True)
    ax.set_facecolor('w')
    plt.axvline(avacado[i].mean(),linestyle='--',label='mean',color='k')
    plt.legend(loc='best')
    plt.title(i,color='navy')
    plt.xlabel('')

# %% [markdown]
# # Observation:

# %% [markdown]
# From above we can see that data is not normalised for some features and we should proceed with the data cleaning.

# %%
avacado.hist(edgecolor='red',linewidth=1.5,figsize=(20,20))
# Out:
# array([[<AxesSubplot:title={'center':'AveragePrice'}>,
#         <AxesSubplot:title={'center':'Total Volume'}>,
#         <AxesSubplot:title={'center':'4046'}>],
#        [<AxesSubplot:title={'center':'4225'}>,
#         <AxesSubplot:title={'center':'4770'}>,
#         <AxesSubplot:title={'center':'Total Bags'}>],
#        [<AxesSubplot:title={'center':'Small Bags'}>,
#         <AxesSubplot:title={'center':'Large Bags'}>,
#         <AxesSubplot:title={'center':'XLarge Bags'}>],
#        [<AxesSubplot:title={'center':'type'}>,
#         <AxesSubplot:title={'center':'year'}>,
#         <AxesSubplot:title={'center':'region'}>]], dtype=object)

# %%
plt.figure(figsize=(10,6))
avacado.corr()['AveragePrice'].sort_values(ascending=False).drop(['AveragePrice']).plot(kind='bar',color='c')
plt.xlabel('Feature',fontsize=14)
plt.ylabel('Correlation with the target column',fontsize=14)
plt.title('Correlation features with the target column',fontsize=14)
plt.show()

# %%
plt.figure(figsize=(10,6))
avacado.corr()['region'].sort_values(ascending=False).drop(['region']).plot(kind='bar',color='orange')
plt.xlabel('Feature',fontsize=14)
plt.ylabel('Correlation with the target column',fontsize=14)
plt.title('Correlation features with the target column',fontsize=14)
plt.show()

# %%
avacado.isnull().sum()
# Out:
# AveragePrice    0
# Total Volume    0
# 4046            0
# 4225            0
# 4770            0
# Total Bags      0
# Small Bags      0
# Large Bags      0
# XLarge Bags     0
# type            0
# year            0
# region          0
# dtype: int64

# %% [markdown]
# None of the columns is having NaN or NaT value.

# %%
avacado.skew()
# Out:
# AveragePrice     0.580303
# Total Volume     9.007687
# 4046             8.648220
# 4225             8.942466
# 4770            10.159396
# Total Bags       9.756072
# Small Bags       9.540660
# Large Bags       9.796455
# XLarge Bags     13.139751
# type             0.000329
# year             0.215339
# region           0.000030
# dtype: float64

# %% [markdown]
# # Skewness:

# %% [markdown]
# We are taking Skewness threshold as +/-0.5. From the following observation, the columns falls under high skewness:
#
# Total Volume, skewness=9.007687, 4046, skewness=8.648220, 4225, skewness=8.942466, 4770, skewness=10.159396, Total Bags, skewness=9.756072, Small Bags, skewness=9.540660, Large Bags, skewness=9.796455, XLarge Bags, skewness=13.139751

# %%
avacado.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18249 entries, 0 to 18248
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   AveragePrice  18249 non-null  float64
#  1   Total Volume  18249 non-null  float64
#  2   4046          18249 non-null  float64
#  3   4225          18249 non-null  float64
#  4   4770          18249 non-null  float64
#  5   Total Bags    18249 non-null  float64
#  6   Small Bags    18249 non-null  float64
#  7   Large Bags    18249 non-null  float64
#  8   XLarge Bags   18249 non-null  float64
#  9   type          18249 non-null  int32
#  10  year          18249 non-null  int64
#  11  region        18249 non-null  int32
# dtypes: float64(9), int32(2), int64(1)
# memory usage: 1.5 MB

# %% [markdown]
# From above we can have columns datatype and memory used by the dataframe.

# %% [markdown]
# # Outliers Checking:

# %% [markdown]
# To check outliers we are box plot.

# %%
avacado.plot(kind='box',subplots=True,layout=(3,4),figsize=(16,20),color='Teal')
plt.xticks(fontsize=16)
plt.yticks(fontsize=12)
plt.show()

# %% [markdown]
# From above we can see that columns ['Total Volume','4046','4225','4770','Total Bags','Small Bags','Large Bags','XLarge Bags']has more outliers, while columns ['type','year']have no outliers. Column 'AveragePrice' and 'region' are target column.

# %% [markdown]
# # Removing outliers:

# %% [markdown]
# Checking the percentage of data falling under outliers:

# %%
from scipy.stats import zscore
import numpy as np

# %%
z=np.abs(zscore(avacado))
z.shape
# Out:
# (18249, 12)

# %%
threshold=3
print(np.where(z>3))
# Out:
# (array([  346,   359,   780, ..., 17304, 17402, 17428], dtype=int64), array([2, 2, 8, ..., 0, 0, 0], dtype=int64))

# %%
avacado_new=avacado[(z<3).all(axis=1)]
print(avacado.shape)
print(avacado_new.shape)
# Out:
# (18249, 12)
# (17651, 12)

# %% [markdown]
# # Percentage Data loss

# %%
loss_percent=(18249-17651)/18249*100
print(loss_percent)
# Out:
# 3.276891884486821

# %% [markdown]
# Percentage loss is not more than 5 percent.

# %% [markdown]
# We will try for IQR.

# %%
Q1=avacado.quantile(0.25)
Q3=avacado.quantile(0.75)
IQR=Q3-Q1
print(IQR)
# Out:
# AveragePrice         0.56
# Total Volume    422123.71
# 4046            110166.13
# 4225            147198.08
# 4770              6243.42
# Total Bags      105694.73
# Small Bags       80488.25
# Large Bags       21901.78
# XLarge Bags        132.50
# type                 1.00
# year                 2.00
# region              27.00
# dtype: float64

# %%
avacado_new1=avacado[-((avacado<(Q1-1.5*IQR)) |(avacado>(Q3 + 1.5 * IQR))).any(axis=1)]
print(avacado_new1.shape)
# Out:
# (11538, 12)

# %%
percentage_loss=(18249-11538)/18249*100
print(percentage_loss)
# Out:
# 36.774617787276014

# %% [markdown]
# Since the percentage loss in zscore is less, we will go with zscore over IQR

# %% [markdown]
# # Dividing data in features and vectors:

# %% [markdown]
# Taking AveragePrice as target column and using Regression.

# %%
x_a=avacado_new.drop(columns=['AveragePrice'])
y_a=avacado_new['AveragePrice']

# %%
x_a.dtypes
# Out:
# Total Volume    float64
# 4046            float64
# 4225            float64
# 4770            float64
# Total Bags      float64
# Small Bags      float64
# Large Bags      float64
# XLarge Bags     float64
# type              int32
# year              int64
# region            int32
# dtype: object

# %% [markdown]
# Observing relationship between features and target vectors.

# %%
plt.figure(figsize=(20,30),facecolor='white')
plotnumber=1

for column in x_a:
    if plotnumber<=16:
        ax=plt.subplot(4,3,plotnumber)
        sns.scatterplot(y_a,x_a[column])
        plt.xlabel('AveragePrice',fontsize=20)
        plt.ylabel(column,fontsize=20)
    plotnumber+=1
plt.tight_layout()

# %% [markdown]
# # Transforming data to remove skewness:

# %%
avacado_new.skew()
# Out:
# AveragePrice    0.377432
# Total Volume    3.767138
# 4046            4.909848
# 4225            4.455745
# 4770            5.117170
# Total Bags      4.066771
# Small Bags      4.222706
# Large Bags      5.053434
# XLarge Bags     6.135607
# type           -0.037741
# year            0.229976
# region          0.012798
# dtype: float64

# %% [markdown]
# Outcome of Skewness the normal skewness is between +/-0.5.
#
# Columns which are still not under the normal skewness range:
#
#     Total Volume
#     4046
#     4225
#     4770
#     Total Bags
#     Small Bags
#     Large Bags
#     XLarge Bags

# %% [markdown]
# Using power_transform to remove the skewness.

# %%
from sklearn.preprocessing import power_transform
x_a=power_transform(x_a,method='yeo-johnson')
x_a
# Out:
# array([[-0.07532391, -0.65742071,  0.35142978, ..., -1.01904715,
#         -1.2106467 , -2.01058988],
#        [-0.14749743, -0.77717852,  0.26951276, ..., -1.01904715,
#         -1.2106467 , -2.01058988],
#        [ 0.20555557, -0.7317763 ,  0.64933326, ..., -1.01904715,
#         -1.2106467 , -2.01058988],
#        ...,
#        [-0.77527398, -0.61796649, -0.77889327, ...,  0.98130886,
#          1.97870686,  1.57828237],
#        [-0.70179733, -0.54701087, -0.71637127, ...,  0.98130886,
#          1.97870686,  1.57828237],
#        [-0.66738095, -0.35967077, -0.79165015, ...,  0.98130886,
#          1.97870686,  1.57828237]])

# %% [markdown]
# Applying Standard Scaler

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
x_at=sc.fit_transform(x_a)
x_at
# Out:
# array([[-0.07532391, -0.65742071,  0.35142978, ..., -1.01904715,
#         -1.21061818, -2.01058988],
#        [-0.14749743, -0.77717852,  0.26951276, ..., -1.01904715,
#         -1.21061818, -2.01058988],
#        [ 0.20555557, -0.7317763 ,  0.64933326, ..., -1.01904715,
#         -1.21061818, -2.01058988],
#        ...,
#        [-0.77527398, -0.61796649, -0.77889327, ...,  0.98130886,
#          1.97873539,  1.57828237],
#        [-0.70179733, -0.54701087, -0.71637127, ...,  0.98130886,
#          1.97873539,  1.57828237],
#        [-0.66738095, -0.35967077, -0.79165015, ...,  0.98130886,
#          1.97873539,  1.57828237]])

# %%
y_a.value_counts()
# Out:
# 1.15    193
# 1.18    191
# 1.26    189
# 1.59    186
# 1.48    185
#        ...
# 0.49      2
# 2.53      2
# 0.44      1
# 0.48      1
# 0.46      1
# Name: AveragePrice, Length: 215, dtype: int64

# %%
print(x_at.shape)
print(y_a.shape)
# Out:
# (17651, 11)
# (17651,)

# %% [markdown]
# # Regressor Model Building:

# %% [markdown]
# # Linear Regression:

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score

# %%
lr=LinearRegression()
max_scr=0
for i in range(0,1000):
    x_train,x_test,y_train,y_test=train_test_split(x_at,y_a,random_state=i,test_size=0.20)
    lr.fit(x_train,y_train)
    pred_train=lr.predict(x_train)
    pred_test=lr.predict(x_test)
    if round(r2_score(y_train,pred_train)*100,2)==round(r2_score(y_test,pred_test)*100,2):
        print('At random state',i,'The model performs well')
        print('At random state:-',i)
        print('Training score is:-',r2_score(y_train,pred_train)*100)
        print('Testing score is:-',r2_score(y_test,pred_test)*100)
# Out:
# At random state 100 The model performs well
# At random state:- 100
# Training score is:- 52.74165358470535
# Testing score is:- 52.741297940017496
# At random state 113 The model performs well
# At random state:- 113
# Training score is:- 52.738421384586985
# Testing score is:- 52.743591368706454
# At random state 307 The model performs well
# At random state:- 307
# Training score is:- 52.74081399692794
# Testing score is:- 52.74432026047498
# At random state 756 The model performs well
# At random state:- 756
# Training score is:- 52.73944041337615
# Testing score is:- 52.743694133171815
# At random state 871 The model performs well
# At random state:- 871
# Training score is:- 52.74470219244982
# Testing score is:- 52.738558268266054
# At random state 986 The model performs well
# At random state:- 986
# Training score is:- 52.728964875139695
# Testing score is:- 52.728737374253456

# %%
x_train_a,x_test_a,y_train_a,y_test_a=train_test_split(x_at,y_a,random_state=986,test_size=0.20)

# %% [markdown]
# We are using random state 986, as at random state 986, it is giving highest accuracy.

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import cross_val_score

# %% [markdown]
# # Regularization

# %% [markdown]
# # 1.Lasso:

# %%
from sklearn.linear_model import Lasso
parameters={'alpha':[0.0001,0.001,0.01,0.1,1,10],'random_state':list(range(0,10))}
ls=Lasso()
grid_search=GridSearchCV(ls,parameters)
grid_search.fit(x_train,y_train)
print(grid_search.best_params_)
# Out:
# {'alpha': 0.0001, 'random_state': 0}

# %%
ls=Lasso(alpha=0.0001,random_state=0)
ls.fit(x_train_a,y_train_a)
ls.score(x_train_a,y_train_a)
pred_ls=ls.predict(x_test_a)

lss=r2_score(y_test_a,pred_ls)
for i in range(2,30):
    lsscore=cross_val_score(ls,x_at,y_a,cv=i)
    lsc=lsscore.mean()
    print('At cv:-',i)
    print('r2_score is:-',lss*100)
    print('cross validation score is:-',lsc*100)
    print('\n')
# Out:
# At cv:- 2
# r2_score is:- 52.734135097382094
# cross validation score is:- -284.18642844580324
#
#
# At cv:- 3
# r2_score is:- 52.734135097382094
# cross validation score is:- 12.396071348588727
#
#
# At cv:- 4
# r2_score is:- 52.734135097382094
# cross validation score is:- 10.429670578881007
#
#
# At cv:- 5
# r2_score is:- 52.734135097382094
# cross validation score is:- 18.048154663835284
#
#
# At cv:- 6
# r2_score is:- 52.734135097382094
# cross validation score is:- 13.186409917138993
#
#
# At cv:- 7
# r2_score is:- 52.734135097382094
# cross validation score is:- 14.761262782952839
#
#
# At cv:- 8
# r2_score is:- 52.734135097382094
# cross validation score is:- 14.639439687821042
#
#
# At cv:- 9
# r2_score is:- 52.734135097382094
# cross validation score is:- 15.427362475964685
#
#
# At cv:- 10
# r2_score is:- 52.734135097382094
# cross validation score is:- 13.365485037399289
#
#
# At cv:- 11
# r2_score is:- 52.734135097382094
# cross validation score is:- 13.45608768462561
#
# ...

# %%
print('At cv:-',5)
print('r2_score is:-',52.73413)
print('cross validation score is:-',18.04815)
# Out:
# At cv:- 5
# r2_score is:- 52.73413
# cross validation score is:- 18.04815

# %%
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
import numpy as np

# %%
print('Error')
print('mean absolute error:',mean_absolute_error(y_test_a,pred_ls))
print('mean squared error:',mean_squared_error(y_test_a,pred_ls))
print('root mean squared error:',np.sqrt(mean_squared_error(y_test_a,pred_ls)))
# Out:
# Error
# mean absolute error: 0.21035388262877106
# mean squared error: 0.07152172153433718
# root mean squared error: 0.267435453024346

# %%
plt.figure(figsize=(8,6))
plt.scatter(x=y_test_a,y=pred_ls,color='b')
plt.plot(y_test_a,y_test_a,color='r')
plt.xlabel('Actual AveragePrice',fontsize=14)
plt.ylabel('Predicted AveragePrice',fontsize=14)
plt.title('Lasso Regression',fontsize=14)
plt.show()

# %% [markdown]
# # 2.Ridge:

# %%
from sklearn.linear_model import Ridge
parameters={'alpha':[0.0001,0.001,0.01,0.1,1,10],'fit_intercept':[True,False],'normalize':[True,False],'copy_X':[True,False],'tol':[0.001,0.01,0.1],'random_state':list(range(0,10))}
rd=Ridge()
clf=GridSearchCV(rd,parameters)
clf.fit(x_train_a,y_train_a)
print(clf.best_params_)
# Out:
# {'alpha': 0.0001, 'copy_X': True, 'fit_intercept': True, 'normalize': True, 'random_state': 0, 'tol': 0.001}

# %%
rd=Ridge(alpha=0.0001,copy_X=True,fit_intercept=True,normalize=True,random_state=0,tol=0.001)
rd.fit(x_train_a,y_train_a)
pred_rd=rd.predict(x_test_a)
rds=r2_score(y_test_a,pred_rd)
print('r2 score is:',rds*100)
rdscore=cross_val_score(rd,x_at,y_a,cv=5)
rdc=rdscore.mean()
print('cross validation score is:',rdc*100)
# Out:
# r2 score is: 52.729384780030685
# cross validation score is: 18.09228047294579

# %%
print('Error')
print('mean absolute error:',mean_absolute_error(y_test_a,pred_rd))
print('mean squared error:',mean_squared_error(y_test_a,pred_rd))
print('root mean squared error:',np.sqrt(mean_squared_error(y_test_a,pred_rd)))
# Out:
# Error
# mean absolute error: 0.2103749574380278
# mean squared error: 0.07152890961553504
# root mean squared error: 0.2674488915952636

# %%
plt.figure(figsize=(8,6))
plt.scatter(x=y_test_a,y=pred_rd,color='b')
plt.plot(y_test_a,y_test_a,color='r')
plt.xlabel('Actual AveragePrice',fontsize=14)
plt.ylabel('Predicted AveragePrice',fontsize=14)
plt.title('Ridge Regression',fontsize=14)
plt.show()

# %% [markdown]
# # Ensemble Techniques:

# %%
from sklearn.tree import DecisionTreeRegressor
parameters={'criterion':['mse','friedman_mse','mae'],'splitter':['best','random'],}
dtr=DecisionTreeRegressor()
clf=GridSearchCV(dtr,parameters)
clf.fit(x_train_a,y_train_a)

print(clf.best_params_)
# Out:
# {'criterion': 'friedman_mse', 'splitter': 'best'}

# %%
dtr=DecisionTreeRegressor(criterion='mse',splitter='best')
dtr.fit(x_train_a,y_train_a)
dtr.score(x_train_a,y_train_a)
pred_dtr=dtr.predict(x_test_a)
dts=r2_score(y_test_a,pred_dtr)
print('r2_score is:',dts*100)

dtscore=cross_val_score(dtr,x_at,y_a,cv=5)
dtc=dtscore.mean()
print('cross validation score is:',dtc*100)
# Out:
# r2_score is: 67.05054705775883
# cross validation score is: -50.812928607441044

# %%
print('Error')
print('mean absolute error:',mean_absolute_error(y_test_a,pred_dtr))
print('mean squared error:',mean_squared_error(y_test_a,pred_dtr))
print('root mean squared error:',np.sqrt(mean_squared_error(y_test_a,pred_dtr)))
# Out:
# Error
# mean absolute error: 0.1475021240441801
# mean squared error: 0.0498584253752478
# root mean squared error: 0.22329000285558645

# %%
plt.figure(figsize=(8,6))
plt.scatter(x=y_test_a,y=pred_dtr,color='b')
plt.plot(y_test_a,y_test_a,color='r')
plt.xlabel('Actual AveragePrice',fontsize=14)
plt.ylabel('Predicted AveragePrice',fontsize=14)
plt.title('Decision Tree Regressor',fontsize=14)
plt.show()

# %%
from sklearn.datasets import make_regression
from sklearn.ensemble import GradientBoostingRegressor
parameters = {'loss' : ['ls', 'lad', 'huber', 'quantile'],'n_estimators':[50,100,200],'criterion':['friedman_mse', 'mse']}
gbr=GradientBoostingRegressor()
clf = GridSearchCV(gbr,parameters)
clf.fit(x_train_a,y_train_a)

print(clf.best_params_)
# Out:
# {'criterion': 'friedman_mse', 'loss': 'ls', 'n_estimators': 200}

# %%
gbr=GradientBoostingRegressor(criterion='friedman_mse',loss='ls',n_estimators=200)
gbr.fit(x_train_a,y_train_a)
gbr.score(x_train_a,y_train_a)
pred_gbr=gbr.predict(x_test_a)
gbrs=r2_score(y_test_a,pred_gbr)
print('r2_score is:',gbrs*100)

gbrscore=cross_val_score(gbr,x_at,y_a,cv=5)
gbrc=gbrscore.mean()
print('cross validation score is:',gbrc*100)
# Out:
# r2_score is: 70.94901328959568
# cross validation score is: 39.20515313979776

# %%
print('Error')
print('mean absolute error:',mean_absolute_error(y_test_a,pred_gbr))
print('mean squared error:',mean_squared_error(y_test_a,pred_gbr))
print('root mean squared error:',np.sqrt(mean_squared_error(y_test_a,pred_gbr)))
# Out:
# Error
# mean absolute error: 0.15545555092760588
# mean squared error: 0.0439593475350577
# root mean squared error: 0.2096648457301741

# %%
plt.figure(figsize=(8,6))
plt.scatter(x=y_test_a,y=pred_gbr,color='b')
plt.plot(y_test_a,y_test_a,color='r')
plt.xlabel('Actual AveragePrice',fontsize=14)
plt.ylabel('Predicted AveragePrice',fontsize=14)
plt.title('Gradient Boost Regressor',fontsize=14)
plt.show()

# %%
from sklearn.svm import SVR

parameters = { 'kernel': ['linear', 'poly','rbf', 'sigmoid'],'gamma':['auto','scale']}
sv = SVR()
clf = GridSearchCV(sv,parameters)
clf.fit(x_train_a,y_train_a)

print(clf.best_params_)
# Out:
# {'gamma': 'auto', 'kernel': 'rbf'}

# %%
sv = SVR(kernel = 'rbf', gamma = 'auto')
sv.fit(x_train_a, y_train_a)
sv.score(x_train_a, y_train_a)
pred_sv = sv.predict(x_test_a)

svs = r2_score(y_test_a,pred_sv)
print('R2 Score:',svs*100)

svscore = cross_val_score(sv,x_at,y_a,cv=5)
svc = svscore.mean() 
print('Cross Val Score:',svc*100)
# Out:
# R2 Score: 70.81014852704371
# Cross Val Score: 1.7844160555068342

# %%
plt.figure(figsize=(8,6))
plt.scatter(x=y_test_a, y=pred_sv, color='b')
plt.plot(y_test_a,y_test_a, color='r')
plt.xlabel('Actual AveragePrice',fontsize=14)
plt.ylabel('Predicted AveragePrice',fontsize=14)
plt.title('Support vector regressor',fontsize=18)
plt.show()

# %% [markdown]
# # The best model is GradientBoostRegressor.Since the difference between the percentage score of cross validation and r2_score is optimum.

# %% [markdown]
# # Conclusion:

# %%
import numpy as np
a=np.array(y_test_a)
predicted=np.array(gbr.predict(x_test_a))
avacado_com=pd.DataFrame({'original':a,'predicted':predicted},index=range(len(a)))
avacado_com
# Out:
#       original  predicted
# 0         1.46   1.455552
# 1         0.95   1.064556
# 2         0.90   0.836834
# 3         1.26   1.289531
# 4         1.07   1.150983
# ...        ...        ...
# 3526      1.46   1.786563
# 3527      1.45   1.629023
# 3528      1.90   1.605838
# 3529      1.04   1.108792
# 3530      1.47   1.496247
#
# [3531 rows x 2 columns]

# %% [markdown]
# # Now taking region as target column.

# %%
x_b=avacado_new.drop(columns=['region'])
y_b=avacado_new['region']

# %%
x_b.dtypes
# Out:
# AveragePrice    float64
# Total Volume    float64
# 4046            float64
# 4225            float64
# 4770            float64
# Total Bags      float64
# Small Bags      float64
# Large Bags      float64
# XLarge Bags     float64
# type              int32
# year              int64
# dtype: object

# %% [markdown]
# Observing relationship between features and target vectors.

# %%
plt.figure(figsize=(20,30),facecolor='white')
plotnumber=1

for column in x_b:
    if plotnumber<=16:
        ax=plt.subplot(4,3,plotnumber)
        sns.scatterplot(y_b,x_b[column])
        plt.xlabel('region',fontsize=20)
        plt.ylabel(column,fontsize=20)
    plotnumber+=1
plt.tight_layout()

# %% [markdown]
# # Removing Skewness:

# %% [markdown]
# Using power_transform to remove the skewness.

# %%
from sklearn.preprocessing import power_transform
x_b=power_transform(x_b,method='yeo-johnson')
x_b
# Out:
# array([[-0.11782446, -0.07532391, -0.65742071, ..., -0.67791909,
#         -1.01904715, -1.2106467 ],
#        [-0.06432986, -0.14749743, -0.77717852, ..., -0.67791909,
#         -1.01904715, -1.2106467 ],
#        [-1.29886469,  0.20555557, -0.7317763 , ..., -0.67791909,
#         -1.01904715, -1.2106467 ],
#        ...,
#        [ 1.18432357, -0.77527398, -0.61796649, ..., -0.67791909,
#          0.98130886,  1.97870686],
#        [ 1.31329624, -0.70179733, -0.54701087, ..., -0.67791909,
#          0.98130886,  1.97870686],
#        [ 0.61561867, -0.66738095, -0.35967077, ..., -0.67791909,
#          0.98130886,  1.97870686]])

# %% [markdown]
# Applying Standard Scaler

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
x_bt=sc.fit_transform(x_b)
x_bt
# Out:
# array([[-0.11782446, -0.07532391, -0.65742071, ..., -0.67791909,
#         -1.01904715, -1.21061818],
#        [-0.06432986, -0.14749743, -0.77717852, ..., -0.67791909,
#         -1.01904715, -1.21061818],
#        [-1.29886469,  0.20555557, -0.7317763 , ..., -0.67791909,
#         -1.01904715, -1.21061818],
#        ...,
#        [ 1.18432357, -0.77527398, -0.61796649, ..., -0.67791909,
#          0.98130886,  1.97873539],
#        [ 1.31329624, -0.70179733, -0.54701087, ..., -0.67791909,
#          0.98130886,  1.97873539],
#        [ 0.61561867, -0.66738095, -0.35967077, ..., -0.67791909,
#          0.98130886,  1.97873539]])

# %%
y_b.value_counts()
# Out:
# 0     338
# 4     338
# 9     338
# 8     338
# 39    338
# 23    338
# 16    338
# 38    338
# 11    338
# 27    338
# 12    338
# 5     338
# 44    338
# 26    338
# 13    338
# 49    338
# 34    338
# 32    338
# 35    338
# 2     338
# 18    338
# 10    338
# 30    338
# 19    338
# 28    337
# 1     337
# 20    337
# 50    336
# 33    336
# 40    336
# 41    336
# 14    336
# 31    335
# 24    335
# 21    333
# 48    333
# 25    333
# 7     332
# 53    332
# 22    331
# 17    331
# 36    330
# 3     329
# 37    328
# 47    328
# 43    326
# 29    325
# 46    307
# 42    301
# 45    292
# 6     290
# 15    272
# 52    256
# 51    169
# Name: region, dtype: int64

# %%
print(x_bt.shape)
print(y_b.shape)
# Out:
# (17651, 11)
# (17651,)

# %% [markdown]
# # Model building:

# %% [markdown]
# # Logistic Regression

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
lr=LogisticRegression()
from sklearn.metrics import accuracy_score

# %%
for i in range(0,100):
    x_train_t,x_test_t,y_train_t,y_test_t=train_test_split(x_bt,y_b,random_state=i,test_size=0.20)
    lr.fit(x_train_t,y_train_t)
    pred_train_t=lr.predict(x_train_t)
    pred_test_t=lr.predict(x_test_t)
    if round(accuracy_score(y_train_t,pred_train_t)*100,1)==round(accuracy_score(y_test_t,pred_test_t)*100,1):
        print('At random state',i,'The model performs very well')
        print('At random state',i)
        print('Training r2_score is:-',accuracy_score(y_train_t,pred_train_t)*100)
        print('Testing r2_score is:-',accuracy_score(y_test_t,pred_test_t)*100)
# Out:
# At random state 20 The model performs very well
# At random state 20
# Training r2_score is:- 55.09206798866856
# Testing r2_score is:- 55.05522514868309
# At random state 22 The model performs very well
# At random state 22
# Training r2_score is:- 55.21246458923513
# Testing r2_score is:- 55.225148683092605
# At random state 39 The model performs very well
# At random state 39
# Training r2_score is:- 55.21954674220964
# Testing r2_score is:- 55.196828094024355
# At random state 61 The model performs very well
# At random state 61
# Training r2_score is:- 55.09915014164306
# Testing r2_score is:- 55.05522514868309
# At random state 66 The model performs very well
# At random state 66
# Training r2_score is:- 55.021246458923514
# Testing r2_score is:- 55.02690455961484
# At random state 76 The model performs very well
# At random state 76
# Training r2_score is:- 55.04249291784703
# Testing r2_score is:- 54.99858397054659

# %%
x_train_b,x_test_b,y_train_b,y_test_b=train_test_split(x_bt,y_b,random_state=66,test_size=0.2)

# %% [markdown]
# At random_state=66, we are getting best accuracy_score.

# %% [markdown]
# # Checking different model building techniques:

# %%
from sklearn.naive_bayes import MultinomialNB
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report

# %%
def svmkernel(ker):
    svc=SVC(kernel=ker)
    svc.fit(x_train_b,y_train_b)
    svc.score(x_train_b,y_train_b)
    pred_svc=svc.predict(x_test_b)
    print(accuracy_score(y_test_b,pred_svc))
    print(confusion_matrix(y_test_b,pred_svc))
    print(classification_report(y_test_b,pred_svc))

# %%
svmkernel('rbf')
# Out:
# 0.8269612007929765
# [[59  0  0 ...  0  0  0]
#  [ 0 46  0 ...  0  0  2]
#  [ 0  0 77 ...  0  0  0]
#  ...
#  [ 0  0  0 ... 32  0  0]
#  [ 0  0  0 ...  0 54  0]
#  [ 0  1  5 ...  0  0 46]]
#               precision    recall  f1-score   support
#
#            0       0.72      0.92      0.81        64
#            1       0.64      0.69      0.66        67
#            2       0.90      1.00      0.94        77
#            3       0.84      0.78      0.81        63
#            4       0.86      0.85      0.85        59
#            5       0.86      0.70      0.78        54
#            6       1.00      0.95      0.97        57
#            7       0.78      0.85      0.81        59
#            8       0.99      0.97      0.98        70
#            9       0.70      0.84      0.77        68
#           10       0.78      0.67      0.72        76
#           11       0.91      0.83      0.87        84
#           12       0.97      0.97      0.97        68
# ...

# %%
svmkernel('linear')
# Out:
# 0.7309544038516002
# [[54  0  0 ...  0  0  0]
#  [ 0 43  0 ...  0  0  0]
#  [ 0  0 75 ...  0  0  0]
#  ...
#  [ 0  0  0 ... 32  0  0]
#  [ 0  0  0 ...  0 55  0]
#  [ 0  3  2 ...  0  0 32]]
#               precision    recall  f1-score   support
#
#            0       0.69      0.84      0.76        64
#            1       0.38      0.64      0.48        67
#            2       0.91      0.97      0.94        77
#            3       0.73      0.71      0.72        63
#            4       0.70      0.85      0.77        59
#            5       0.56      0.57      0.57        54
#            6       0.96      0.95      0.96        57
#            7       0.78      0.76      0.77        59
#            8       0.88      0.97      0.93        70
#            9       0.75      0.75      0.75        68
#           10       0.74      0.61      0.67        76
#           11       0.85      0.83      0.84        84
#           12       0.85      0.88      0.86        68
# ...

# %%
svmkernel('poly')
# Out:
# 0.7326536391956953
# [[48  0  0 ...  0  0  0]
#  [ 0 44  0 ...  0  0  0]
#  [ 0  0 71 ...  0  0  0]
#  ...
#  [ 0  0  0 ... 32  0  0]
#  [ 0  0  0 ...  1 54  0]
#  [ 0  3  0 ...  0  0 34]]
#               precision    recall  f1-score   support
#
#            0       0.65      0.75      0.70        64
#            1       0.48      0.66      0.56        67
#            2       0.91      0.92      0.92        77
#            3       0.84      0.78      0.81        63
#            4       0.82      0.78      0.80        59
#            5       0.71      0.50      0.59        54
#            6       1.00      0.79      0.88        57
#            7       0.76      0.54      0.63        59
#            8       0.99      0.97      0.98        70
#            9       0.66      0.82      0.73        68
#           10       0.63      0.55      0.59        76
#           11       0.91      0.86      0.88        84
#           12       0.82      0.88      0.85        68
# ...

# %%
svmkernel('sigmoid')
# Out:
# 0.08297932596998017
# [[ 9  0  0 ...  0  0  0]
#  [ 0  2  0 ...  0  0  0]
#  [ 0  0  5 ...  0  0  0]
#  ...
#  [ 0  0  0 ...  0  3  0]
#  [ 0  0  0 ... 15  1  0]
#  [ 2  0  0 ...  0  0  0]]
#               precision    recall  f1-score   support
#
#            0       0.11      0.14      0.12        64
#            1       0.13      0.03      0.05        67
#            2       0.29      0.06      0.11        77
#            3       0.04      0.05      0.04        63
#            4       0.17      0.07      0.10        59
#            5       0.09      0.04      0.05        54
#            6       0.05      0.14      0.07        57
#            7       0.29      0.03      0.06        59
#            8       0.50      0.09      0.15        70
#            9       0.20      0.16      0.18        68
#           10       0.33      0.09      0.14        76
#           11       0.00      0.00      0.00        84
#           12       0.13      0.04      0.07        68
# ...

# %% [markdown]
# Here we can see svmkernel('rbf') is having best accuracy_score

# %% [markdown]
# Checking for Decision tree and KNN.

# %%
knn=KNeighborsClassifier(n_neighbors=5)
knn.fit(x_train_b,y_train_b)
knn.score(x_train_b,y_train_b)
knn_pred=knn.predict(x_test_b)
print(accuracy_score(y_test_b,knn_pred))
print(confusion_matrix(y_test_b,knn_pred))
print(classification_report(y_test_b,knn_pred))
# Out:
# 0.8411214953271028
# [[59  0  0 ...  0  0  0]
#  [ 0 50  0 ...  0  0  1]
#  [ 0  0 72 ...  0  0  0]
#  ...
#  [ 0  0  0 ... 32  0  0]
#  [ 0  0  0 ...  0 55  0]
#  [ 0  0  2 ...  0  0 50]]
#               precision    recall  f1-score   support
#
#            0       0.77      0.92      0.84        64
#            1       0.71      0.75      0.73        67
#            2       0.92      0.94      0.93        77
#            3       0.88      0.83      0.85        63
#            4       0.89      0.93      0.91        59
#            5       0.83      0.72      0.77        54
#            6       0.98      0.96      0.97        57
#            7       0.82      0.93      0.87        59
#            8       0.92      0.96      0.94        70
#            9       0.67      0.76      0.71        68
#           10       0.78      0.70      0.74        76
#           11       0.95      0.92      0.93        84
#           12       0.97      0.94      0.96        68
# ...

# %%
dtc=DecisionTreeClassifier()
dtc.fit(x_train_b,y_train_b)
dtc.score(x_train_b,y_train_b)
dtc_pred=dtc.predict(x_test_b)
print(accuracy_score(y_test_b,dtc_pred))
print(confusion_matrix(y_test_b,dtc_pred))
print(classification_report(y_test_b,dtc_pred))
# Out:
# 0.7960917587085812
# [[44  0  0 ...  0  0  0]
#  [ 0 53  0 ...  0  0  0]
#  [ 0  0 68 ...  0  0  0]
#  ...
#  [ 0  0  0 ... 32  0  0]
#  [ 0  0  0 ...  0 54  0]
#  [ 0  1  2 ...  0  0 47]]
#               precision    recall  f1-score   support
#
#            0       0.86      0.69      0.77        64
#            1       0.70      0.79      0.74        67
#            2       0.88      0.88      0.88        77
#            3       0.79      0.78      0.78        63
#            4       0.91      0.88      0.90        59
#            5       0.63      0.78      0.69        54
#            6       0.95      1.00      0.97        57
#            7       0.81      0.86      0.84        59
#            8       0.93      0.97      0.95        70
#            9       0.75      0.87      0.80        68
#           10       0.69      0.58      0.63        76
#           11       0.89      0.86      0.87        84
#           12       0.88      0.87      0.87        68
# ...

# %% [markdown]
# Here KNN is performing well than DTC, and for final model we will use KNN, value.

# %% [markdown]
# # Applying Hyperparameter Tuning Grid:

# %%
from sklearn.model_selection import GridSearchCV, RandomizedSearchCV

# %%
grid_param={'leaf_size':list(range(1,10)),'n_neighbors':list(range(1,10)),'p':[1,2]}

# %%
grid_search=GridSearchCV(knn,param_grid=grid_param,cv=20)

# %%
grid_search.fit(x_train_b,y_train_b)
# Out:
# GridSearchCV(cv=20,
#              estimator=KNeighborsClassifier(leaf_size=1, n_neighbors=1, p=1),
#              param_grid={'leaf_size': [1, 2, 3, 4, 5, 6, 7, 8, 9],
#                          'n_neighbors': [1, 2, 3, 4, 5, 6, 7, 8, 9],
#                          'p': [1, 2]})

# %%
print(grid_search.best_estimator_)
# Out:
# KNeighborsClassifier(leaf_size=1, n_neighbors=1, p=1)

# %% [markdown]
# Here we found the best estimator using GridSearch.

# %%
grid_search.best_score_
# Out:
# 0.8907223796033994

# %%
knn=KNeighborsClassifier(leaf_size=1,n_neighbors=1,p=1)
knn.fit(x_train_b,y_train_b)
# Out:
# KNeighborsClassifier(leaf_size=1, n_neighbors=1, p=1)

# %%
knn.score(x_test_b,y_test_b)
# Out:
# 0.885868026054942

# %% [markdown]
# Great!! Our score has improved after using GridSearch.

# %%
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import cross_val_score
import numpy as np

# %%
knn=KNeighborsClassifier(leaf_size=1,n_neighbors=1,p=1)
knn.fit(x_train_b,y_train_b)
knn.score(x_train_b,y_train_b)
pred_knn=knn.predict(x_test_b)

knn_r=r2_score(y_test_b,pred_knn)
print('r2_score is:-',knn_r*100)

knn_score=cross_val_score(knn,x_bt,y_b,cv=20)
knn_c=knn_score.mean()
print('cross_val_score:-',knn_c*100)
# Out:
# r2_score is:- 78.45722692081061
# cross_val_score:- 75.73847017100536

# %%
print('Error:')
print('mean absolute error:',mean_absolute_error(y_test_b,pred_knn))
print('mean squared error:',mean_squared_error(y_test_b,pred_knn))
print('root mean square error',np.sqrt(mean_squared_error(y_test_b,pred_knn)))
# Out:
# Error:
# mean absolute error: 2.0147267063154914
# mean squared error: 51.31804021523648
# root mean square error 7.163661090199374

# %%
#predict the value
print('predicted region',pred_knn)
print('actual region',y_test_b)
# Out:
# predicted region [ 7 49 16 ... 29 52  0]
# actual region 11117    38
# 9426      5
# 15390    12
# 64        1
# 5240     46
#          ..
# 14508    49
# 14316    45
# 17960    29
# 5559     52
# 10        0
# Name: region, Length: 3531, dtype: int32

# %% [markdown]
# # Since the model without outliers performing well, we will select that dataframe.

# %% [markdown]
# # Model Saving:

# %%
import pickle
filename='avacado_project.pk2'
pickle.dump(knn,open(filename,'wb'))

# %% [markdown]
# # Conclusion:

# %%
import numpy as np
b=np.array(y_test_b)
predicted_b=np.array(knn.predict(x_test_b))
avacado_com_b=pd.DataFrame({'original':b,'predicted':predicted_b},index=range(len(b)))
avacado_com_b
# Out:
#       original  predicted
# 0           38          7
# 1            5         49
# 2           12         16
# 3            1          1
# 4           46         46
# ...        ...        ...
# 3526        49         49
# 3527        45         45
# 3528        29         29
# 3529        52         52
# 3530         0          0
#
# [3531 rows x 2 columns]
